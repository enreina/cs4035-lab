# %%
import pandas as pd
import random
import heapq
import operator
import numpy as np
from collections import defaultdict

# %% [markdown]
# Let's read the dataset in chunks. You need to download the dataset from here https://mcfp.felk.cvut.cz/publicDatasets/CTU-Malware-Capture-Botnet-43/capture20110811.pcap.netflow.labeled and put it in the `dataset` folder

# %%
# read in 100 chunk size
dataset = pd.read_csv('dataset/capture20110811.pcap.netflow.labeled', delim_whitespace=True, chunksize=1000)

# %%
first_chunk = dataset.get_chunk()
first_chunk
# Out:
#      #Date_flow         start  Durat Prot       Src_IP_Addr:Port  ->  \
# 0    2011-08-11  10:10:00.003  0.967  UDP       89.31.8.11:23929  ->
# 1    2011-08-11  10:10:00.003  0.967  UDP    147.32.84.229:13363  ->
# 2    2011-08-11  10:10:00.006  0.000  UDP     208.88.186.6:34042  ->
# 3    2011-08-11  10:10:00.008  0.000  UDP    92.118.218.77:55246  ->
# 4    2011-08-11  10:10:00.009  0.000  UDP  182.185.139.181:10223  ->
# 5    2011-08-11  10:10:00.011  0.000  UDP    147.32.84.229:13363  ->
# 6    2011-08-11  10:10:00.011  0.000  UDP    147.32.84.229:13363  ->
# 7    2011-08-11  10:10:00.013  0.000  UDP     86.27.118.198:6386  ->
# 8    2011-08-11  10:10:00.014  0.000  UDP    147.32.84.229:13363  ->
# 9    2011-08-11  10:10:00.015  0.839  TCP  197.195.116.160:49177  ->
# 10   2011-08-11  10:10:00.020  0.000  UDP    213.246.38.78:64117  ->
# 11   2011-08-11  10:10:00.023  0.000  UDP    147.32.84.229:13363  ->
# 12   2011-08-11  10:10:00.027  0.215  UDP   194.165.188.87:16723  ->
# 13   2011-08-11  10:10:00.028  0.215  UDP    147.32.84.229:13363  ->
# 14   2011-08-11  10:10:00.029  0.000  UDP   86.186.242.169:38574  ->
# 15   2011-08-11  10:10:00.029  0.000  UDP    147.32.84.229:13363  ->
# 16   2011-08-11  10:10:00.035  0.000  TCP    79.48.232.124:52332  ->
# 17   2011-08-11  10:10:00.038  1.998  UDP    147.32.84.229:13363  ->
# 18   2011-08-11  10:10:00.040  0.000  UDP    147.32.84.229:13363  ->
# 19   2011-08-11  10:10:00.040  0.000  UDP    147.32.84.229:13363  ->
# 20   2011-08-11  10:10:00.040  0.000  UDP    147.32.84.229:13363  ->
# 21   2011-08-11  10:10:00.041  0.000  UDP   217.117.248.175:4845  ->
# 22   2011-08-11  10:10:00.041  3.516  TCP   174.143.151.71:54399  ->
# 23   2011-08-11  10:10:00.041  3.362  TCP   174.143.151.71:54399  ->
# 24   2011-08-11  10:10:00.041  0.000  UDP    147.32.84.229:13363  ->
# 25   2011-08-11  10:10:00.054  0.000  UDP    147.32.84.229:13363  ->
# 26   2011-08-11  10:10:00.073  0.000  UDP   109.205.114.167:7750  ->
# 0      147.32.84.229:13363    INT    0        2    135      1
# 1         89.31.8.11:23929    INT    0        2    276      1
# 2      147.32.84.229:13363    INT    0        1     62      1
# 3      147.32.84.229:13363    INT    0        1     78      1
# 4      147.32.84.229:13363    INT    0        1     72      1
# 5      92.118.218.77:55246    INT    0        1     60      1
# 6    182.185.139.181:10223    INT    0        1     60      1
# 7      147.32.84.229:13363    INT    0        1     77      1
# 8       86.27.118.198:6386    INT    0        1     60      1
# 9      147.32.84.229:13363    PA_    0        3   1512      1
# 10     147.32.84.229:13363    INT    0        1    479      1
# 11     213.246.38.78:64117    INT    0        1     60      1
# 12     147.32.84.229:13363    INT    0        2    151      1
# 13    194.165.188.87:16723    INT    0        2    526      1
# 14     147.32.84.229:13363    INT    0        1     75      1
# 15    86.186.242.169:38574    INT    0        1     60      1
# 16     147.32.84.229:13363     S_    0        1     62      1
# 17      87.20.151.25:62268    INT    0        2    358      1
# 18       1.168.131.80:6112    INT    0        1     73      1
# 19     46.119.32.188:58283    INT    0        1     74      1
# 20   190.244.141.231:21586    INT    0        1     78      1
# 21     147.32.84.229:13363    INT    0        1     75      1
# 22        147.32.87.190:22  FSPA_    0       12   1320      1
# 23        147.32.87.190:22  _FSPA    0       14   2588      1
# 24    217.117.248.175:4845    INT    0        1     60      1
# 25     90.177.224.29:10012    INT    0        1    104      1
# 26     147.32.84.229:13363    INT    0        1     76      1
# 27    109.205.114.167:7750    INT    0        1     60      1
# 28     147.32.84.229:13363    INT    0        1     75      1
# 29    188.24.130.122:14787    INT    0        1     60      1
# ..                     ...    ...  ...      ...    ...    ...
# 970     74.125.232.230:443     A_    0        1     60      1
# 971     85.71.215.81:25420    PA_    0        3    286      1
# 972    147.32.84.229:13363    INT    0        1     75      1
# 973   99.136.226.223:21206    INT    0        1     60      1
# 974   186.85.253.148:57546    INT    0        1    141      1
# 975    147.32.84.229:13363    INT    0        1     75      1
# 976    59.124.25.236:50813    INT    0        1     60      1
# 977      147.32.86.99:9378     A_    0        1     66      1
# 978    147.32.84.229:13363    PA_    0        3    223      1
# 979      147.32.86.74:1062    PA_    0        1     62      1
# 980    147.32.84.229:13363    INT    0        1     63      1
# 981    147.32.84.229:13363    INT    0        1     75      1
# 982     212.25.47.56:19470    INT    0        1     60      1
# 983     74.125.232.218:443     A_    0        1     66      1
# 984    147.32.84.229:13363    INT    0        1     74      1
# 985     77.31.61.161:61642    INT    0        1     60      1
# 986     89.24.140.27:10238    INT    0        1     75      1
# 987    98.219.201.25:61966    INT    0        2    144      1
# 988   78.251.219.181:52087    PA_    0        2    123      1
# 989     147.32.84.59:50253     A_    0        1     66      1
# 990     147.32.87.20:10010     A_    0        1     60      1
# 991      24.32.30.215:2465    INT    0        1    177      1
# 992      209.85.148.83:443     A_    0        1     60      1
# 993      147.32.85.7:49595    FA_    0        2    132      1
# 994      147.32.85.7:44876    FA_    0        2    132      1
# 995      174.36.110.197:80  _FSPA    0        4    775      1
# 996    147.32.84.229:13363    INT    0        1     69      1
# 997    147.32.84.229:13363    INT    0        1     74      1
# 998    147.32.84.229:13363    INT    0        1     73      1
# 999    196.216.11.213:2885    INT    0        1     60      1
#
#     Label(LEGITIMATE:Botnet:Background)
# 0                            Background
# 1                            Background
# 2                            Background
# 3                            Background
# 4                            Background
# 5                            Background
# 6                            Background
# 7                            Background
# 8                            Background
# 9                            Background
# 10                           Background
# 11                           Background
# 12                           Background
# 13                           Background
# 14                           Background
# 15                           Background
# 16                           Background
# 17                           Background
# 18                           Background
# 19                           Background
# 20                           Background
# 21                           Background
# 22                           Background
# 23                           Background
# 24                           Background
# 25                           Background
# 26                           Background
# 27                           Background
# 28                           Background
# 29                           Background
# ..                                  ...
# 970                          LEGITIMATE
# 971                          Background
# 972                          Background
# 973                          Background
# 974                          Background
# 975                          Background
# 976                          Background
# 977                          Background
# 978                          Background
# 979                          Background
# 980                          Background
# 981                          Background
# 982                          Background
# 983                          LEGITIMATE
# 984                          Background
# 985                          Background
# 986                          Background
# 987                          Background
# 988                          Background
# 989                          Background
# 990                          Background
# 991                          Background
# 992                          LEGITIMATE
# 993                          Background
# 994                          Background
# 995                          Background
# 996                          Background
# 997                          Background
# 998                          Background
# 999                          Background
#
# [1000 rows x 13 columns]

# %%
# preprocess: clean up columns
def preprocess(chunk):
    chunk = chunk.rename(index=str, columns={
        "#Date_flow": "Date",
        "start": "Start",
        "Durat": "Duration",
        "Prot":"Protocol",
        "Src_IP_Addr:Port" : "Source_IP",
        "Dst_IP_Addr:Port": "Destination_IP",
        "Label(LEGITIMATE:Botnet:Background)": "Label"})
    chunk = chunk.drop(axis="columns", labels="->")
    
    chunk['Source_IP'] = chunk['Source_IP'].apply(lambda x: x.split(":")[0])
    chunk['Destination_IP'] = chunk['Destination_IP'].apply(lambda x: x.split(":")[0])
    return chunk

first_chunk = preprocess(first_chunk)
first_chunk.head()
# Out:
#          Date         Start  Duration Protocol        Source_IP  \
# 0  2011-08-11  10:10:00.003     0.967      UDP       89.31.8.11
# 1  2011-08-11  10:10:00.003     0.967      UDP    147.32.84.229
# 2  2011-08-11  10:10:00.006     0.000      UDP     208.88.186.6
# 3  2011-08-11  10:10:00.008     0.000      UDP    92.118.218.77
# 4  2011-08-11  10:10:00.009     0.000      UDP  182.185.139.181
#
#   Destination_IP Flags  Tos  Packets  Bytes  Flows       Label
# 0  147.32.84.229   INT    0        2    135      1  Background
# 1     89.31.8.11   INT    0        2    276      1  Background
# 2  147.32.84.229   INT    0        1     62      1  Background
# 3  147.32.84.229   INT    0        1     78      1  Background
# 4  147.32.84.229   INT    0        1     72      1  Background

# %% [markdown]
# We can see from the rows that the host IP address from which the network flows were captured is `147.32.84.229`

# %% [markdown]
# ## True Frequency

# %%
dataset_all = pd.read_csv('dataset/capture20110811.pcap.netflow.labeled', delim_whitespace=True)

# %%
dataset_all = preprocess(dataset_all)
len(dataset_all)
# Out:
# 6351188

# %%
true_freq_ip = dataset_all['Source_IP'].append(dataset_all['Destination_IP']).value_counts()
true_freq_ip[:11] # we list 11 most frequent IP as we don't want to consider the host IP
# Out:
# 147.32.84.229    3405103
# 147.32.80.9      1147493
# 147.32.84.138     643319
# 147.32.84.59      634581
# 147.32.86.165     156522
# 147.32.80.13       63305
# 147.32.85.25       62616
# 147.32.84.118      56830
# 147.32.84.165      54433
# 147.32.84.171      51413
# 147.32.85.124      46499
# dtype: int64

# %%
true_freq_ip[:11] / float(len(dataset_all))
# Out:
# 147.32.84.229    0.536136
# 147.32.80.9      0.180674
# 147.32.84.138    0.101291
# 147.32.84.59     0.099915
# 147.32.86.165    0.024645
# 147.32.80.13     0.009967
# 147.32.85.25     0.009859
# 147.32.84.118    0.008948
# 147.32.84.165    0.008571
# 147.32.84.171    0.008095
# 147.32.85.124    0.007321
# dtype: float64

# %% [markdown]
# ## Min-Wise Sampling
# 1. Read the dataset in chunksize=1
# 2. For each incoming sample, generate random number *hashtag* between [0,1] assign to the sample
# 3. Keep k samples with smallest hashtag (we use priority queue `heapq`)

# %%
count = 0
priority_queue = [] # we use heapq for priority queue implementation
# not really streaming the data, we just simulate the min-wise sampling
for index, chunk in dataset_all.iterrows():
    hashtag = random.random()
    ip_address = chunk["Source_IP"]
    heapq.heappush(priority_queue, (hashtag,ip_address))
    
    hashtag = random.random()
    ip_address = chunk["Destination_IP"]
    heapq.heappush(priority_queue, (hashtag,ip_address))
        
    count = count + 1

# %%
# reservoir size
k = 10000
ip_address_samples = []
temp_priority_queue = list(priority_queue)
for i in range(k):
    sample = heapq.heappop(temp_priority_queue)
    ip_address = sample[1]
    ip_address_samples.append(ip_address)

# %%
freq_ip = pd.Series(ip_address_samples).value_counts()
freq_ip[:11]
# Out:
# 147.32.84.229    2725
# 147.32.80.9       905
# 147.32.84.59      488
# 147.32.84.138     482
# 147.32.86.165     118
# 147.32.85.25       53
# 147.32.80.13       50
# 147.32.84.165      44
# 147.32.84.118      42
# 147.32.84.171      42
# 147.32.84.131      36
# dtype: int64

# %%
freq_ip[:11] / float(k)
# Out:
# 147.32.84.229    0.2725
# 147.32.80.9      0.0905
# 147.32.84.59     0.0488
# 147.32.84.138    0.0482
# 147.32.86.165    0.0118
# 147.32.85.25     0.0053
# 147.32.80.13     0.0050
# 147.32.84.165    0.0044
# 147.32.84.118    0.0042
# 147.32.84.171    0.0042
# 147.32.84.131    0.0036
# dtype: float64
